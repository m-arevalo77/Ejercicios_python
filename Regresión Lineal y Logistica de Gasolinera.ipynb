# %% [markdown]
# #Regresión Lineal y Logistica de Estación de gasolina

# %% [markdown]
# 1.Importamos librerías

# %%
import numpy as np
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2.Cargamos el dataset

# %%
df_gas = pd.read_csv("https://raw.githubusercontent.com/luisFernandoCastellanosG/Machine_learning/master/Databaset_para_trabajar_sklearn/petrol_consumption.csv")
df_gas.head()
# Out:
#    gasolina_impuesto  ...  gasolina_Consumo
# 0                9.0  ...               541
# 1                9.0  ...               524
# 2                9.0  ...               561
# 3                7.5  ...               414
# 4                8.0  ...               410
#
# [5 rows x 5 columns]

# %% [markdown]
# 3.Cantidad de Filas, valores null y estadisticas del dataset

# %%
print(f'Cantidad de Filas: {df_gas.shape[0]}')
print(f'Valore Null: {df_gas.isnull().values.any()}')
df_gas.describe()
# Out:
# Cantidad de Filas: 48
# Valore Null: False
#        gasolina_impuesto  ...  gasolina_Consumo
# count          48.000000  ...         48.000000
# mean            7.668333  ...        576.770833
# std             0.950770  ...        111.885816
# min             5.000000  ...        344.000000
# 25%             7.000000  ...        509.500000
# 50%             7.500000  ...        568.500000
# 75%             8.125000  ...        632.750000
# max            10.000000  ...        968.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# Descripción de las columnas

# %%
df_gas.columns
# Out:
# Index(['gasolina_impuesto', 'ingreso_promedio', 'carreteras_pavimentadas',
#        'porcen_licencias_conducion_poblacion', 'gasolina_Consumo'],
#       dtype='object')

# %% [markdown]
# Graficamos datos

# %%
sns.pairplot(df_gas)

# %%
sns.set(rc={'figure.figsize':(18,7)})
sns.heatmap(data=df_gas.corr(), annot=True)

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.distplot(df_gas['gasolina_Consumo'])
plt.show()

# %% [markdown]
# #Regresion Lineal

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.linear_model  import LogisticRegression

for col in df_gas.columns[:-1]:
  y = df_gas['gasolina_Consumo']
  x = df_gas.drop('gasolina_Consumo', axis=1)
  x_train, x_test, y_train, y_test=train_test_split(x,y, test_size=0.2)
  regressor= LinearRegression()
  regressor.fit(x_train, y_train)
  y_pred = regressor.predict(x_test)
  sns.set(rc={'figure.figsize':(10,5)})
  plt.scatter(x_train[col],y_train,linewidth=6)
  plt.scatter(x_test[col],y_pred,color='yellow',linewidths=1)
  plt.title('Regresión Lineal')
  plt.xlabel(col)
  plt.ylabel('gasolina_Consumo')
  plt.show()
  print('\n Presición del modelo')
  print(regressor.score(x_train, y_train))
# Out:
#  Presición del modelo
# 0.6794991065820898
#  Presición del modelo
# 0.6417812889860944
#  Presición del modelo
# 0.6574426840239815
#  Presición del modelo
# 0.6504590863876243

# %% [markdown]
# #Regresión Logistica

# %%
for col in  df_gas.columns[:-1]:
  y= df_gas['gasolina_Consumo']
  x = df_gas.drop('gasolina_Consumo', axis=1)
  x_train,x_test,y_train, y_test = train_test_split(x, y, test_size=0.2)

  regressor = LinearRegression()
  log_regresor = regressor.fit(x_train,y_train)
  y_pred = log_regresor.predict(x_test)

  sns.set(rc={'figure.figsize':(10,5)})

  plt.scatter(x_train[col],y_train,linewidth=6)
  plt.scatter(x_test[col],y_pred,color='yellow',linewidths=1)
  plt.title('Regresion Logistica')
  plt.xlabel(col)
  plt.ylabel('gasolina_Consumo')
  plt.show()

  print('PRESICION DEL MODELO ')
  print(regressor.score(x_train,y_train))
# Out:
# PRESICION DEL MODELO
# 0.6407101190823326
# PRESICION DEL MODELO
# 0.6082693555680528
# PRESICION DEL MODELO
# 0.7033999386653378
# PRESICION DEL MODELO
# 0.6768740991432699
